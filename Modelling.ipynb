# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filePath = 'Data/sector_51_daily_aqi_cleaned.csv'
dataFrame = pd.read_csv(filePath)
print(dataFrame.head(5))
# Out:
#    Unnamed: 0        Date    AQI   Date_date  Year  Month
# 0           0  2020-03-05   73.0  2020-03-05  2020      3
# 1           1  2020-03-06   55.0  2020-03-06  2020      3
# 2           2  2020-03-07   78.0  2020-03-07  2020      3
# 3           3  2020-03-08  120.0  2020-03-08  2020      3
# 4           4  2020-03-09  179.0  2020-03-09  2020      3

# %%
plt.figure(figsize=(15, 6))
plt.plot(dataFrame['Date'],dataFrame['AQI'], label='AQI')
plt.xlabel('Date')
plt.ylabel('AQI')
plt.title('Daily AQI Over Time')
plt.legend()
plt.grid(True)
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(10)) # Show only 10 dates to avoid clutter
plt.gcf().autofmt_xdate() # Rotate date labels

plt.show()
